# %%
import warnings
import networkx as nx
import matplotlib.pyplot as plt
import random
warnings.filterwarnings('ignore')

# %%
#the file was downloaded from: https://snap.stanford.edu/data/ego-Facebook.html
filename = "facebook_combined.txt"

data = open(filename)

G = nx.read_edgelist(data, delimiter=' ', nodetype=str)

N = len(G.nodes)
E = len(G.edges)
maxE = int(N*(N-1)/2)
print(N)
print()

degree_dist = {}
avg_degree = 0
for node in G.nodes():
    node_degree = len(G[node])
    if node_degree not in degree_dist:
        degree_dist[node_degree] = 0
    degree_dist[node_degree] += 1
    avg_degree += node_degree
avg_degree = avg_degree/N


print("Average degree -", round(avg_degree, 2))
print("Number of edges -", E)
print("Max Number of edges -", maxE)
print("Density -", round(E/maxE, 3))
print("Min Degree -", min(degree_dist.keys()))
print("Max Degree -", max(degree_dist.keys()))



fig= plt.figure(figsize=(16,12))

#plt.yscale('log',basey=2)
#plt.xscale('log',basey=2)
plt.scatter(list(degree_dist.keys()), list(degree_dist.values()), color='g')


plt.show()
# Out:
# 4039
#
# Average degree - 43.69
# Number of edges - 88234
# Max Number of edges - 8154741
# Density - 0.011
# Min Degree - 1
# Max Degree - 1045

# %%
## Star graph

import networkx as nx
import matplotlib.pyplot as plt
import random

G=nx.Graph()
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")
G.add_node("F")
G.add_node("G")

G.add_edge("A", "B")
G.add_edge("A", "C")
G.add_edge("A", "D")
G.add_edge("A", "E")
G.add_edge("A", "F")
G.add_edge("A", "G")

Cd = nx.degree_centrality(G)
Cb = nx.betweenness_centrality(G)
Cc = nx.closeness_centrality(G)

print("Node","\t", "Degree","\t", "Betweeness","\t", "Closeness")
for n in G.nodes():
    print(n,"\t", round(Cd[n], 2),"\t\t", round(Cb[n], 2),"\t\t", round(Cc[n], 2))

nx.draw(G, with_labels=True, node_size=1000, node_color="skyblue")
plt.show()
# Out:
# Node 	 Degree 	 Betweeness 	 Closeness
# A 	 1.0 		 1.0 		 1.0
# B 	 0.17 		 0.0 		 0.55
# C 	 0.17 		 0.0 		 0.55
# D 	 0.17 		 0.0 		 0.55
# E 	 0.17 		 0.0 		 0.55
# F 	 0.17 		 0.0 		 0.55
# G 	 0.17 		 0.0 		 0.55

# %%
## Circle graph

import networkx as nx
import matplotlib.pyplot as plt
import random

G=nx.Graph()
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")
G.add_node("F")
G.add_node("G")

G.add_edge("A", "B")
G.add_edge("B", "C")
G.add_edge("C", "D")
G.add_edge("D", "E")
G.add_edge("E", "F")
G.add_edge("F", "G")
G.add_edge("G", "A")

Cd = nx.degree_centrality(G)
Cb = nx.betweenness_centrality(G)
Cc = nx.closeness_centrality(G)

print("Node","\t", "Degree","\t", "Betweeness","\t", "Closeness")
for n in G.nodes():
    print(n,"\t", round(Cd[n], 2),"\t\t", round(Cb[n], 2),"\t\t", round(Cc[n], 2))


nx.draw(G, with_labels=True, node_size=1000, node_color="skyblue")
plt.show()
# Out:
# Node 	 Degree 	 Betweeness 	 Closeness
# A 	 0.33 		 0.2 		 0.5
# B 	 0.33 		 0.2 		 0.5
# C 	 0.33 		 0.2 		 0.5
# D 	 0.33 		 0.2 		 0.5
# E 	 0.33 		 0.2 		 0.5
# F 	 0.33 		 0.2 		 0.5
# G 	 0.33 		 0.2 		 0.5

# %%
## Line graph

import networkx as nx
import matplotlib.pyplot as plt
import random

G=nx.Graph()
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")
G.add_node("F")
G.add_node("G")

G.add_edge("A", "B")
G.add_edge("B", "C")
G.add_edge("C", "D")
G.add_edge("D", "E")
G.add_edge("E", "F")
G.add_edge("F", "G")

Cd = nx.degree_centrality(G)
Cb = nx.betweenness_centrality(G)
Cc = nx.closeness_centrality(G)

print("Node","\t", "Degree","\t", "Betweeness","\t", "Closeness")
for n in G.nodes():
    print(n,"\t", round(Cd[n], 2),"\t\t", round(Cb[n], 2),"\t\t", round(Cc[n], 2))

nx.draw(G, with_labels=True, node_size=1000, node_color="skyblue")
plt.show()
# Out:
# Node 	 Degree 	 Betweeness 	 Closeness
# A 	 0.17 		 0.0 		 0.29
# B 	 0.33 		 0.33 		 0.38
# C 	 0.33 		 0.53 		 0.46
# D 	 0.33 		 0.6 		 0.5
# E 	 0.33 		 0.53 		 0.46
# F 	 0.33 		 0.33 		 0.38
# G 	 0.17 		 0.0 		 0.29

# %%
import networkx as nx

G = nx.florentine_families_graph()
plt.figure(3,figsize=(26,15))
nx.draw(G, with_labels=True, node_size=3000, node_color="skyblue", font_size=30)

Cd = nx.degree_centrality(G)
Cb = nx.betweenness_centrality(G)
Cc = nx.closeness_centrality(G)

for n in G.nodes():
    l = 20 - len(n)
    print(n," "*l, round(Cd[n], 2),"\t", round(Cb[n], 2),"\t", round(Cc[n], 2))

plt.show()
# Out:
# Acciaiuoli            0.07 	 0.0 	 0.37
# Medici                0.43 	 0.52 	 0.56
# Castellani            0.21 	 0.05 	 0.39
# Peruzzi               0.21 	 0.02 	 0.37
# Strozzi               0.29 	 0.1 	 0.44
# Barbadori             0.14 	 0.09 	 0.44
# Ridolfi               0.21 	 0.11 	 0.5
# Tornabuoni            0.21 	 0.09 	 0.48
# Albizzi               0.21 	 0.21 	 0.48
# Salviati              0.14 	 0.14 	 0.39
# Pazzi                 0.07 	 0.0 	 0.29
# Bischeri              0.21 	 0.1 	 0.4
# Guadagni              0.29 	 0.25 	 0.47
# Ginori                0.07 	 0.0 	 0.33
# Lamberteschi          0.07 	 0.0 	 0.33

# %%
##Erdos-Renyi model

import networkx as nx
import random

G = nx.Graph()

N = 30
p = 0.3

num_of_edges = 0

my_nodes = list(x for x in range(0, N))
for n1 in my_nodes:
    G.add_node(n1)
    for n2 in my_nodes:
        if n1>n2:
            rand = random.uniform(0, 1)
            if rand <= p:
                G.add_edge(n1, n2)
                num_of_edges += 1

degree_dist = {}
avg_degree = 0
for node in G.nodes():
    node_degree = len(G[node])
    if node_degree not in degree_dist:
        degree_dist[node_degree] = 0
    degree_dist[node_degree] += 1
    avg_degree += node_degree
avg_degree = avg_degree/N

print("N =", N, ", p =", p)
print("Average degree -", avg_degree)
print("Number of edges -", num_of_edges)
print("Max Number of edges -", int(N*(N-1)/2))



plt.bar(list(degree_dist.keys()), list(degree_dist.values()), color='g')

if(N <= 100):
    plt.figure(3,figsize=(20,20))
    pos = nx.spring_layout(G,scale=2)
    nx.draw(G, pos, with_labels=True, node_size=1000, node_color="skyblue", font_size=15)
plt.show()
# Out:
# N = 30 , p = 0.3
# Average degree - 8.333333333333334
# Number of edges - 125
# Max Number of edges - 435

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

n = 2000
p = 0.02

G = nx.erdos_renyi_graph(n, p)


degree_dist = {}
avg_degree = 0
for node in G.nodes():
    node_degree = len(G[node])
    if node_degree not in degree_dist:
        degree_dist[node_degree] = 0
    degree_dist[node_degree] += 1
    avg_degree += node_degree
avg_degree = avg_degree/N



plt.bar(list(degree_dist.keys()), list(degree_dist.values()), color='g')

if(n <= 100):
    plt.figure(3,figsize=(10,10))
    pos = nx.circular_layout(G)
    nx.draw(G, pos, with_labels=True, node_size=1000, node_color="skyblue", font_size=15)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

n = 30
p = 0.1
k = 4

G = nx.watts_strogatz_graph(n, k, p, seed=None)

degree_dist = {}
avg_degree = 0
for node in G.nodes():
    node_degree = len(G[node])
    if node_degree not in degree_dist:
        degree_dist[node_degree] = 0
    degree_dist[node_degree] += 1
    avg_degree += node_degree
avg_degree = avg_degree/N



plt.bar(list(degree_dist.keys()), list(degree_dist.values()), color='g')

if(n <= 100):
    plt.figure(3,figsize=(10,10))
    pos = nx.circular_layout(G)
    nx.draw(G, pos, with_labels=True, node_size=1000, node_color="skyblue", font_size=15)
plt.show()

# %%
import networkx as nx

G = nx.watts_strogatz_graph(25, 2, 0)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_size=400, node_color="skyblue", font_size=15)
plt.show()

G = nx.watts_strogatz_graph(25, 2, 0.35)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_size=400, node_color="skyblue", font_size=15)
plt.show()

G = nx.watts_strogatz_graph(25, 2, 1)
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, node_size=400, node_color="skyblue", font_size=15)
plt.show()

# %%
import networkx as nx

G = nx.florentine_families_graph()
plt.figure(3,figsize=(26,15))

Cb = nx.betweenness_centrality(G)
Cc = nx.closeness_centrality(G)
Cd = nx.degree_centrality(G)


nx.draw(G, with_labels=True, node_color="skyblue", font_size=30, node_size=[v*50000 for v in Cc.values()])
plt.show()
